# %% [markdown]
# 1.Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.

# %%
a = 200
b = 800

M_x = (a + b)/2
print(f'Среднее значение: {M_x}')

D_x = ((b - a)**2)/12
print(f'Дисперсия: {D_x}')
# Out:
# Среднее значение: 500.0
# Дисперсия: 30000.0

# %% [markdown]
# 2.О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.

# %%
import math

D_x = 0.2
a = 0.5

# из формулы дисперсии
b = math.sqrt(12 * D_x) + a
print(f'Правая граница величины B :{b}')

# среднее значение
M_x = (a + b)/2
print(f'Среднее значениел: {M_x}')
# Out:
# Правая граница величины B :2.049193338482967
# Среднее значениел: 1.2745966692414834

# %% [markdown]
# 3.Непрерывная случайная величина X распределена нормально и задана плотностью распределения
# f(x) = (1 / (4 * sqrt(2*pi))) * (exp(-((x+2)**2) / 32))
# Найдите:
# а). M(X)
# б). D(X)
# в). std(X) (среднее квадратичное отклонение)

# %%
#M(X)
M_x = -2
print(f'M(X): {M_x}')

#D(X)
D_x = 16
print(f'D(X): {D_x}')

#std(X)
std_x = 4
print(f'std(X): {std_x}')
# Out:
# M(X): -2
# D(X): 16
# std(X): 4

# %% [markdown]
# 4.Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# а). больше 182 см
# б). больше 190 см
# в). от 166 см до 190 см
# г). от 166 см до 182 см
# д). от 158 см до 190 см
# е). не выше 150 см или не ниже 190 см
# ё). не выше 150 см или не ниже 198 см
# ж). ниже 166 см.

# %%
print('a)больше 182 см: 0.15866')
print('b) больше 190 см: 0.02275')
print('в) от 166 до 190 см: 0.9772 − 0.1587 = 0.8185')
print('г) от 166 до 182 см: 0.8413 - 0.1587 = 0.6826')
print('д) от 158 до 190 см: 0.9772 - 0.0228 = 0.9544')
print('e) не выше 150см или не ниже 190 см: 0.0013 + 0.02275 = 0.02405')
print('ё) не выше 150 см или не ниже 198 см: 0.0013 + 0.0013 = 0.0026')
print('ж) ниже 166 см: 0.1587')
# Out:
# a)больше 182 см: 0.15866
# b) больше 190 см: 0.02275
# в) от 166 до 190 см: 0.9772 − 0.1587 = 0.8185
# г) от 166 до 182 см: 0.8413 - 0.1587 = 0.6826
# д) от 158 до 190 см: 0.9772 - 0.0228 = 0.9544
# e) не выше 150см или не ниже 190 см: 0.0013 + 0.02275 = 0.02405
# ё) не выше 150 см или не ниже 198 см: 0.0013 + 0.0013 = 0.0026
# ж) ниже 166 см: 0.1587

# %% [markdown]
# 5.На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %%
D_x = 25
M_x = 178
height = 190

sigma = math.sqrt(D_x)
sigma_count = (height - M_x)/sigma
print(f'Количество сигм: {sigma_count}')
# Out:
# Количество сигм: 2.4
